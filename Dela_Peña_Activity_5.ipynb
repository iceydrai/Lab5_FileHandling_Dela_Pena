# %%
# Step 1: Import Path from pathlib
from pathlib import Path

# %%
# Step 2: Define a custom folder in your Documents directory
output_dir = Path.home() / "Documents" / "PythonFiles"
output_dir.mkdir(exist_ok=True) # Creates folder if missing

# %%
# Step 3: Define the file path
file_path = output_dir / "Act5_example.txt"

# %%
# Step 4: Write text to the file
with open(file_path, "w", encoding="utf-8") as file:
    file.write("Hello, Welcome to Python Programming!\n")
    file.write("File saved safely with pathlib.")

# %%
# Step 5: Confirm that the file is saved
print(f"File saved to: {file_path.resolve()}")
# Out:
# File saved to: C:\Users\ADRIAN\Documents\PythonFiles\Act5_example.txt

# %%
# Step 1: Read the entire file content if it exists
if file_path.exists():
    with open(file_path, "r", encoding="utf-8") as file:
        content = file.read()
        print("File content:\n", content)
# Out:
# File content:
#  Hello, Welcome to Python Programming!
# File saved safely with pathlib.

# %%
with open(file_path, "r", encoding="utf-8") as file:
    for line_number, line in enumerate(file, 1):
        words = line.split()
        print(f"Line {line_number} has {len(words)} words")
# Out:
# Line 1 has 5 words
# Line 2 has 5 words

# %%
# Step 1: Open file in append mode
with open(file_path, "a", encoding="utf-8") as file:
    file.write("\nThis line was added!")

# %%
# Step 1: Open file in append mode
with open(file_path, "a", encoding="utf-8") as file:
    file.write("\nThis line was added!")

# %%
# Step 1: Import additional libraries
from datetime import datetime
import shutil

# %%
# Step 2: Define working directory
backup_dir = Path.home() / "Documents" / "PythonFiles"
backup_dir.mkdir(exist_ok=True)

# %%
from datetime import datetime
import shutil

# Step 3: Define a function to write a file with backup
def write_with_backup(filename: str, content: str):
    file_path = backup_dir / filename

    # Create backup if file exists
    if file_path.exists():
        timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")
        backup_path = file_path.with_name(
            f"{file_path.stem}_backup_{timestamp}{file_path.suffix}"
        )
        shutil.copy2(file_path, backup_path)
        print(f"Backup saved: {backup_path.name}")

    # Write the new content
    with open(file_path, "w", encoding="utf-8") as file:
        file.write(content)

    print(f"File saved: {file_path.name}")

# %%
# Step 4: Define a function to read the file content
def read_file(filename: str):
    file_path = backup_dir / filename
    with open(file_path, "r", encoding="utf-8") as file:
        content = file.read()
    return content

# %%
# Step 5: Run demonstration
print("=== File Operations Demo ===")

print("\n1. Creating new file:")
write_with_backup("demo.txt", "Initial content")

print("\n2. Updating file (with backup):")
write_with_backup("demo.txt", "Updated content")

print("\n3. Reading file:")
print(read_file("demo.txt"))

print("\n4. Listing backups:")
for backup in backup_dir.glob("*backup*"):
    print("-", backup.name)
# Out:
# === File Operations Demo ===
#
# 1. Creating new file:
# Backup saved: demo_backup_20260428_202129.txt
# File saved: demo.txt
#
# 2. Updating file (with backup):
# Backup saved: demo_backup_20260428_202129.txt
# File saved: demo.txt
#
# 3. Reading file:
# Updated content
#
# 4. Listing backups:
# - Act5_example_Dela_Peña_backup_20260427_054216.txt
# - Dela_Peña_Activity_5_backup_20260427_054917
# - demo_backup_20260427_053835.txt
# - demo_backup_20260428_202129.txt

# %%
if file_path.exists():
    timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")
    backup_path = file_path.with_name(
        f"{file_path.stem}_Dela_Peña_backup_{timestamp}{file_path.suffix}"
    )
    shutil.copy2(file_path, backup_path)
    print(f"Backup saved: {backup_path.name}")
# Out:
# Backup saved: Act5_example_Dela_Peña_backup_20260428_202129.txt

# %%
# Step 1: Import required modules
# Menu-Driven File Manager

from pathlib import Path
from datetime import datetime
import shutil

# %%
# Step 2: Working directory (UPDATED as required)
backup_dir = Path.home() / "Documents" / "Surname_Activity_5"
backup_dir.mkdir(exist_ok=True)

# %%
# Step 3: File Manager Function
def file_manager():
    file_name = input("Enter filename (e.g., notes.txt): ")
    file_path = backup_dir / file_name

    while True:
        print("\n--- MENU ---")
        print("1. Write to file")
        print("2. Append to file")
        print("3. Read file")
        print("4. Backup file")
        print("5. Exit")
        print("6. List backup files")

        choice = input("Choose an option (1-6): ")

        # 1. Write
        if choice == "1":
            content = input("Enter content to write:\n")
            with open(file_path, "w", encoding="utf-8") as f:
                f.write(content)
            print("File written successfully.")

        # 2. Append
        elif choice == "2":
            more = input("Enter content to append:\n")
            with open(file_path, "a", encoding="utf-8") as f:
                f.write("\n" + more)
            print("Content appended.")

        # 3. Read
        elif choice == "3":
            if file_path.exists():
                with open(file_path, "r", encoding="utf-8") as f:
                    print("\nFile Content:\n", f.read())
            else:
                print("File not found.")

        # 4. Backup (UPDATED with surname)
        elif choice == "4":
            if file_path.exists():
                timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")
                backup_file = file_path.with_name(
                    f"{file_path.stem}_DelaPena_backup_{timestamp}{file_path.suffix}"
                )
                shutil.copy2(file_path, backup_file)
                print(f"Backup created: {backup_file.name}")
            else:
                print("Cannot backup. File does not exist.")

        # 5. Exit
        elif choice == "5":
            print("Exiting file manager.")
            break

        # 6. List backups (NEW FEATURE)
        elif choice == "6":
            backups = list(backup_dir.glob("*DelaPena_backup*"))
            if backups:
                print("\nBackup files:")
                for b in backups:
                    print("-", b.name)
            else:
                print("No backup files found.")

        else:
            print("Invalid choice. Please try again.")

# %%
# Step 4: Run program
if __name__ == "__main__":
    file_manager()
# Out:
# --- MENU ---
# 1. Write to file
# 2. Append to file
# 3. Read file
# 4. Backup file
# 5. Exit
# 6. List backup files
# Invalid choice. Please try again.
#
# --- MENU ---
# 1. Write to file
# 2. Append to file
# 3. Read file
# 4. Backup file
# 5. Exit
# 6. List backup files
# Invalid choice. Please try again.
#
# --- MENU ---
# 1. Write to file
# 2. Append to file
# 3. Read file
# 4. Backup file
# 5. Exit
# 6. List backup files
# Invalid choice. Please try again.
#
# --- MENU ---
# 1. Write to file
# 2. Append to file
# 3. Read file
# 4. Backup file
# 5. Exit
# 6. List backup files
# Invalid choice. Please try again.
#
# --- MENU ---
# 1. Write to file
# 2. Append to file
# 3. Read file
# 4. Backup file
# 5. Exit
# 6. List backup files
# Invalid choice. Please try again.
#
# --- MENU ---
# 1. Write to file
# 2. Append to file
# 3. Read file
# 4. Backup file
# 5. Exit
# 6. List backup files
# Exiting file manager.
